# %%
#configure plotting
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import matplotlib;matplotlib.rcParams['figure.figsize'] = (8,5)
import matplotlib;matplotlib.rcParams['text.usetex'] = True
import matplotlib;matplotlib.rcParams['font.size'] = 16
import matplotlib;matplotlib.rcParams['font.family'] = 'serif'
import GPy
import numpy as np
from matplotlib import pyplot as plt
np.random.seed(1)

# %% [markdown]
# # A brief guide to GP classification with GPy
#
# ### James Hensman, November 2014
# #### with edits by Alan Saul
#
# Gaussian Process classification is perhaps the most popular case of a GP model where the likelihood is not conjugate to the prior. In the classification case, the likelihood is Bernoulli, and we must perform approximate inference over the values of the function that in turn model the probability of observing one of the two possible classes. There are many approaches to making such an approximation: here we'll start with the popular EP method.

# %% [markdown]
# ## The generative model
#
# To illustate GP classification, we'll first consider the generative model of the data. In classification, we consider the labels (0 or 1) to be generated by a conditional distribution given the inputs, $\mathbf X$.
#
# In GP classification, the model is that there is a hidden function, drawn from a GP, which takes continuous values. Those values are then squashed through a probit function,  into the range $[0, 1]$, and can then be used as probabilities. Bernoulli draws are then made (taking the values 0 or 1) conditioned on the squashed values.
#
# First we'll set up a kernel for the GP from which to draw some latent function values (a candidate hidden function for the above generative model), given some arbitrary positions $\mathbf X$ at which we get observations.

# %%
k = GPy.kern.RBF(1, variance=7., lengthscale=0.2)
X = np.random.rand(200,1)

#draw the latent function value
f = np.random.multivariate_normal(np.zeros(200), k.K(X))

plt.plot(X, f, 'bo')
plt.title('latent function values');plt.xlabel('$x$');plt.ylabel('$f(x)$')
# Out:
#  /Users/alansaul/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: RuntimeWarning:covariance is not positive-semidefinite.

# %% [markdown]
# Now we'll squash the latent function values through the probit function. We'll set up a GPy likelihood for this, which contains the squashing probit function as well as assorted mechanisms for doing approximate inference.

# %%
lik = GPy.likelihoods.Bernoulli()
p = lik.gp_link.transf(f) # squash the latent function
plt.plot(X, p, 'ro')
plt.title('latent probabilities');plt.xlabel('$x$');plt.ylabel('$\sigma(f(x))$')

# %% [markdown]
# Now binary Bernoulli variables are drawn using the squashed values of our latent function as probabilities:

# %%
Y = lik.samples(f).reshape(-1,1) # sample from the likelihood, conditioned on the values f
plt.plot(X, Y, 'kx', mew=2);plt.ylim(-0.1, 1.1)
plt.title('Bernoulli draws');plt.xlabel('$x$');plt.ylabel('$y \in \{0,1\}$')

# %% [markdown]
# ## Inference
# We have now generated some data from our proposed model. We'll now attempt to model this generated data with a GP classification model.
#
# In this case we wish to know, given the observed binary variables, can we recover the latent function, the associated probabilities, and the variance and lengthscale of the GP that we believe produced the data?
#
# We'll set up a GPy classifier to do this. First we'll use the most general setup for defining a GP object in GPy, allowing us to select the EP inference method and use our existing likelihood and kernel.

# %%
expanded_m = GPy.core.GP(X=X,
                Y=Y, 
                kernel=k, 
                inference_method=GPy.inference.latent_function_inference.expectation_propagation.EP(),
                likelihood=lik)
print(expanded_m)
# Out:
# Name : gp
# Objective : 101.526034549
# Number of Parameters : 2
# Number of Optimization Parameters : 2
# Updates : True
# Parameters:
#   gp.              |  value  |  constraints  |  priors
#   rbf.variance     |    7.0  |      +ve      |
#   rbf.lengthscale  |    0.2  |      +ve      |

# %% [markdown]
# There's a simpler way to build GP classifiers, with some default options (RBF kernel, EP inference) like so:

# %%
m = GPy.models.GPClassification(X,Y)

# %% [markdown]
# This new model is initialized with incorrect lengthscale and variance, but let's check out how it's fared in inferring the latent fuction values:

# %%
m.plot_f()
plt.plot(X, f, 'bo', label='real latent function')
plt.ylabel('$f(x)$');plt.xlabel('$x$')
plt.title("$p(\mathbf{f}^{*}|\mathbf{y})$")
plt.legend()

m.plot_f(apply_link=True)
plt.ylabel('$\Phi^{-1}(f(x))$');plt.xlabel('$x$')
plt.title("$p(\Phi^{-1}(\mathbf{f}^{*})|\mathbf{y})$")

m.plot()
plt.ylabel('$p(\mathbf{y}^{*}=1|\mathbf{y})$');plt.xlabel('$x$')
plt.title("$p(\mathbf{y}^{*}=1|\mathbf{y})$")
# Out:
#  /Users/alansaul/anaconda/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning:This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.

# %% [markdown]
# In the above plots we see:
# - our approximation, $f(x)$, to the true latent function at new predictive points $\mathbf{x}^{*}$ (top)
# - our squashed latent function, $p(\Phi^{-1}(\mathbf{f}^{*})|\mathbf{y})$, this represents the probability of the observations being class 1 (middle) at $\mathbf{x}^{*}$.
# - the posterior of the predictive values of the class, $p(\mathbf{Y}^{*}|\mathbf{Y})$, (bottom)
#
# In the lower plot, the mean of this distribution (dark blue) shows that clearly higher values of $\mathbf{x}$ are less likely to give rise to observations of class 1. Lower values of $\mathbf{x}$ are more likely to give observations of class 0. It may seem strange that the 95% confidence intervals (in blue) extend the full range between 0 and 1, however this is because the output is discrete and hence the 95% confidence intervals are somewhat non-sensical.
#
# In the middle plot which represents the probability of observing class 1 the 95% confidence intervals are more interpretable, they show how uncertain we are about the function representing these proabbilities.
#
# We've already run EP to obtain the approximate posterior and marginal likelihood. The above plots suggest that the lengthscale of the kernel is incorrect for this problem, so we'll optimize the parameters of the kernel against the approximate marginal likelihood, $p(y|\mathcal{M})$, that represents how probable the data is given our model, $\mathcal{M}$.
#
# To do this, we interleave runs of EP with optimization of the hyper-parameters using gradient descent method. EP is a method for fitting a Gaussian process to the posterior, $p(f|y)$, of the latent (hidden) function, given the data. Whilst the parameters are being optimized, the EP approximation (the parameters of the EP factors) is fixed.
#
# This is the default behaviour of the EP algorithm (and hence used within the GPClassification model), alternatively the line:
#
#     GPy.inference.latent_function_inference.expectation_propagation.EP()
#
# above, could be replaced with:
#
#     GPy.inference.latent_function_inference.expectation_propagation.EP(ep_mode='nested')
#
# this will result in slower but more accurate optimisation routine.

# %%
print(m)
print('\n')
for i in range(10):
    m.optimize('bfgs', max_iters=10) #first runs EP and then optimizes the kernel parameters
    print('iteration: {}'.format(i))
    print(m)
    print("")
# Out:
# Name : gp_classification
# Objective : 114.557648428
# Number of Parameters : 2
# Number of Optimization Parameters : 2
# Updates : True
# Parameters:
#   gp_classification.  |  value  |  constraints  |  priors
#   rbf.variance        |    1.0  |      +ve      |
#   rbf.lengthscale     |    1.0  |      +ve      |
#
#
# iteration: 0
#
# Name : gp_classification
# Objective : 101.135048167
# Number of Parameters : 2
# Number of Optimization Parameters : 2
# Updates : True
# Parameters:
#   gp_classification.  |           value  |  constraints  |  priors
#   rbf.variance        |  0.949468425155  |      +ve      |
#   rbf.lengthscale     |  0.140898234994  |      +ve      |
#
# iteration: 1
#
# Name : gp_classification
# Objective : 99.6130690984
# Number of Parameters : 2
# Number of Optimization Parameters : 2
# Updates : True
# Parameters:
#   gp_classification.  |           value  |  constraints  |  priors
#   rbf.variance        |   1.23489386107  |      +ve      |
#   rbf.lengthscale     |  0.137501179974  |      +ve      |
#
# iteration: 2
#
# Name : gp_classification
# Objective : 99.6083762283
# Number of Parameters : 2
# Number of Optimization Parameters : 2
# Updates : True
# Parameters:
#   gp_classification.  |           value  |  constraints  |  priors
#   rbf.variance        |    1.2426325335  |      +ve      |
#   rbf.lengthscale     |  0.137210288667  |      +ve      |
#
# iteration: 3
#
# Name : gp_classification
# Objective : 99.6083625523
# Number of Parameters : 2
# Number of Optimization Parameters : 2
# Updates : True
# Parameters:
#   gp_classification.  |           value  |  constraints  |  priors
#   rbf.variance        |   1.24267319408  |      +ve      |
#   rbf.lengthscale     |  0.137189458404  |      +ve      |
#
# iteration: 4
#
# Name : gp_classification
# Objective : 99.6083621895
# Number of Parameters : 2
# Number of Optimization Parameters : 2
# Updates : True
# Parameters:
#   gp_classification.  |           value  |  constraints  |  priors
#   rbf.variance        |   1.24270955549  |      +ve      |
#   rbf.lengthscale     |  0.137183813153  |      +ve      |
#
# iteration: 5
#
# Name : gp_classification
# Objective : 99.6083621645
# Number of Parameters : 2
# Number of Optimization Parameters : 2
# Updates : True
# Parameters:
#   gp_classification.  |           value  |  constraints  |  priors
#   rbf.variance        |   1.24271481579  |      +ve      |
#   rbf.lengthscale     |  0.137185572968  |      +ve      |
#
# iteration: 6
#
# Name : gp_classification
# Objective : 99.6083621559
# Number of Parameters : 2
# Number of Optimization Parameters : 2
# Updates : True
# Parameters:
#   gp_classification.  |           value  |  constraints  |  priors
#   rbf.variance        |   1.24273089668  |      +ve      |
#   rbf.lengthscale     |  0.137188026287  |      +ve      |
#
# iteration: 7
#
# Name : gp_classification
# Objective : 99.608362133
# Number of Parameters : 2
# Number of Optimization Parameters : 2
# Updates : True
# Parameters:
#   gp_classification.  |           value  |  constraints  |  priors
#   rbf.variance        |   1.24284807167  |      +ve      |
#   rbf.lengthscale     |  0.137185130169  |      +ve      |
#
# iteration: 8
#
# Name : gp_classification
# Objective : 99.6083621232
# Number of Parameters : 2
# Number of Optimization Parameters : 2
# Updates : True
# Parameters:
#   gp_classification.  |           value  |  constraints  |  priors
#   rbf.variance        |   1.24284947039  |      +ve      |
#   rbf.lengthscale     |  0.137187170471  |      +ve      |
#
# iteration: 9
#
# Name : gp_classification
# Objective : 99.6083621192
# Number of Parameters : 2
# Number of Optimization Parameters : 2
# Updates : True
# Parameters:
#   gp_classification.  |           value  |  constraints  |  priors
#   rbf.variance        |   1.24285154336  |      +ve      |
#   rbf.lengthscale     |  0.137188524743  |      +ve      |

# %% [markdown]
# Now our parameters have been optimised to the values that give the largest marginal likelihood, we can plot the results to see how they differ from the original data.

# %%
m.plot_f(apply_link=True)
plt.plot(X, p, 'ro', label='Truth')
plt.ylabel('$f(x)$');plt.xlabel('$x$')
plt.legend()

# %%
m.plot_f(apply_link=True)
plt.plot(X, p, 'ro', label='Truth')
plt.ylabel('$f(x)$');plt.xlabel('$x$')
plt.legend()
plt.savefig('basic_classification.png')

# %% [markdown]
# The above plots are much more satisfactory: we have managed to infer the correct form of the latent function (and hence its squashed counterpart). We note that it's also possible to run MCMC to obtain Bayesian marginalization of the kernel parameters instead of the (type-II) maximum likelihood approach here. Marginalising the hyperparameters could be done with Hamiltonian Monte Carlo (HMC).
#
# We've seen the generating process for GP classification, and how to set up models in GPy to do classification. We've used EP to infer the latent function, interleaved with optimization of the kernel parameters. There are other latent-function inference methods in GPy, such as the Laplace approximation and the forthcoming variational approximation. These are illustrated in accompanying notebooks.
